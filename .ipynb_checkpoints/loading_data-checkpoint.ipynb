# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
food_desert = pd.ExcelFile('data/DataDownload2015.xlsx')

# %%
food_desert.sheet_names
# Out:
# ['Read Me', 'Variable Lookup', 'Food Access Research Atlas']

# %%
desert_data = food_desert.parse(2)

# %%
desert_data.head()
# Out:
#                State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# CensusTract
# 1001020100   Alabama  Autauga      1     1912      693                  0
# 1001020200   Alabama  Autauga      1     2170      743                  0
# 1001020300   Alabama  Autauga      1     3373     1256                  0
# 1001020400   Alabama  Autauga      1     4386     1722                  0
# 1001020500   Alabama  Autauga      1    10766     4082                  0
#
#              NUMGQTRS  PCTGQTRS  LILATracts_1And10  LILATracts_halfAnd10  \
# CensusTract
# 1001020100          0  0.000000                  0                     0
# 1001020200        181  0.083410                  0                     0
# 1001020300          0  0.000000                  0                     0
# 1001020400          0  0.000000                  0                     0
# 1001020500        181  0.016812                  0                     0
#
# ...

# %%
desert_data.describe()
# Out:
#         CensusTract         Urban       POP2010       OHU2010  \
# count  7.286400e+04  72864.000000  72864.000000  72864.000000
# mean   2.783045e+10      0.757191   4237.285052   1601.837560
# std    1.581256e+10      0.428783   1972.520112    732.106217
# min    1.001020e+09      0.000000      0.000000      0.000000
# 25%    1.212708e+10      1.000000   2883.750000   1102.000000
# 50%    2.712979e+10      1.000000   4002.000000   1521.000000
# 75%    4.103900e+10      1.000000   5323.000000   2018.000000
# max    5.604595e+10      1.000000  37452.000000  16043.000000
#
#        GroupQuartersFlag      NUMGQTRS      PCTGQTRS  LILATracts_1And10  \
# count       72864.000000  72864.000000  72864.000000       72864.000000
# mean            0.007082    109.619606      0.026961           0.126880
# std             0.083855    442.922669      0.095494           0.332841
# min             0.000000      0.000000      0.000000           0.000000
# ...

# %%
desert_data['LILATracts_halfAnd10'].sum()/len(desert_data['LILATracts_halfAnd10'])
# Out:
# 0.28211462450592883

# %%
(desert_data['LILATracts_halfAnd10']==True).sum()
# Out:
# 20556

# %%
desert_data.set_index('CensusTract', inplace=True)

# %%
desert_data.head()
# Out:
#                State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# CensusTract
# 1001020100   Alabama  Autauga      1     1912      693                  0
# 1001020200   Alabama  Autauga      1     2170      743                  0
# 1001020300   Alabama  Autauga      1     3373     1256                  0
# 1001020400   Alabama  Autauga      1     4386     1722                  0
# 1001020500   Alabama  Autauga      1    10766     4082                  0
#
#              NUMGQTRS  PCTGQTRS  LILATracts_1And10  LILATracts_halfAnd10  \
# CensusTract
# 1001020100          0  0.000000                  0                     0
# 1001020200        181  0.083410                  0                     0
# 1001020300          0  0.000000                  0                     0
# 1001020400          0  0.000000                  0                     0
# 1001020500        181  0.016812                  0                     0
#
# ...

# %%
subset = desert_data[['TractWhite',
'TractBlack',
'TractAsian',
'TractNHOPI',
'TractAIAN',
'TractOMultir',
'TractHispanic',
'TractHUNV',
'TractSNAP',
'OHU2010','PovertyRate','LILATracts_halfAnd10']]

# %%
subset.corr()
# Out:
#                       TractWhite  TractBlack  TractAsian  TractNHOPI  \
# TractWhite              1.000000   -0.291355    0.026259   -0.022940
# TractBlack             -0.291355    1.000000   -0.022547   -0.016877
# TractAsian              0.026259   -0.022547    1.000000    0.232605
# TractNHOPI             -0.022940   -0.016877    0.232605    1.000000
# TractAIAN              -0.027595   -0.036294   -0.020537    0.012537
# TractOMultir            0.031963    0.087669    0.242747    0.216638
# TractHispanic           0.103793    0.042297    0.148643    0.076254
# TractHUNV              -0.076065    0.282382    0.132868    0.000130
# TractSNAP               0.027851    0.462447   -0.085327    0.044128
# OHU2010                 0.791273    0.149657    0.234302    0.052494
# PovertyRate            -0.344175    0.326662   -0.110024    0.002837
# LILATracts_halfAnd10   -0.226630    0.257653   -0.090609    0.023638
#
# ...

# %%
subset=subset[['PovertyRate','TractSNAP','LILATracts_halfAnd10']]

# %%
behav = pd.read_csv('data/500_Cities__Census_Tract-level_Data__GIS_Friendly_Format___2018_release.csv',)

# %%
behav.head()
# Out:
#   StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0        AL  Birmingham     107000  1073000100  0107000-01073000100
# 1        AL  Birmingham     107000  1073000300  0107000-01073000300
# 2        AL  Birmingham     107000  1073000400  0107000-01073000400
# 3        AL  Birmingham     107000  1073000500  0107000-01073000500
# 4        AL  Birmingham     107000  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               23.3      (20.6, 26.3)                 31.3
# 1            2735               28.5      (25.2, 31.7)                 30.2
# 2            3338               23.9      (20.5, 27.6)                 31.7
# 3            2864               25.8      (22.0, 29.9)                 35.6
# 4            2577               29.4      (24.8, 34.2)                 37.2
#
#   ARTHRITIS_Crude95CI                ...                 PAPTEST_Crude95CI  \
# ...

# %%
behav.set_index('TractFIPS', inplace=True)
behav.dropna(axis=0,inplace=True)

# %%
select_behav=[]
for i in behav.columns:
    if '95CI' not in i:
        select_behav.append(i)

# %%
behav1 = behav[select_behav]

# %%
behav1.corr()
# Out:
#                         PlaceFIPS  Population2010  ACCESS2_CrudePrev  \
# PlaceFIPS                1.000000       -0.053874           0.180361
# Population2010          -0.053874        1.000000           0.045114
# ACCESS2_CrudePrev        0.180361        0.045114           1.000000
# ARTHRITIS_CrudePrev      0.171873       -0.231140           0.089043
# BINGE_CrudePrev         -0.010098        0.071499          -0.460170
# BPHIGH_CrudePrev         0.108873       -0.212074           0.316954
# BPMED_CrudePrev          0.192759       -0.173837          -0.052557
# CANCER_CrudePrev        -0.021564       -0.137155          -0.399004
# CASTHMA_CrudePrev        0.194646       -0.152425           0.301961
# CHD_CrudePrev            0.087093       -0.192115           0.337195
# CHECKUP_CrudePrev        0.197300       -0.167519          -0.103440
# CHOLSCREEN_CrudePrev    -0.089926       -0.056964          -0.649159
# COLON_SCREEN_CrudePrev  -0.115643        0.005327          -0.847519
# ...

# %%
behav1=behav1[['Population2010','PlaceName','TEETHLOST_CrudePrev','STROKE_CrudePrev','PHLTH_CrudePrev','OBESITY_CrudePrev','MHLTH_CrudePrev','LPA_CrudePrev','KIDNEY_CrudePrev','DENTAL_CrudePrev','DIABETES_CrudePrev','CSMOKING_CrudePrev','COREW_CrudePrev','COPD_CrudePrev','CHOLSCREEN_CrudePrev','CASTHMA_CrudePrev','ACCESS2_CrudePrev']]

# %%
t2 = behav1.merge(subset, how='left', left_index=True, right_index=True)

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24866 entries, 1073000100 to 56021002000
# Data columns (total 20 columns):
# Population2010          24866 non-null int64
# PlaceName               24866 non-null object
# TEETHLOST_CrudePrev     24866 non-null float64
# STROKE_CrudePrev        24866 non-null float64
# PHLTH_CrudePrev         24866 non-null float64
# OBESITY_CrudePrev       24866 non-null float64
# MHLTH_CrudePrev         24866 non-null float64
# LPA_CrudePrev           24866 non-null float64
# KIDNEY_CrudePrev        24866 non-null float64
# DENTAL_CrudePrev        24866 non-null float64
# DIABETES_CrudePrev      24866 non-null float64
# CSMOKING_CrudePrev      24866 non-null float64
# COREW_CrudePrev         24866 non-null float64
# COPD_CrudePrev          24866 non-null float64
# CHOLSCREEN_CrudePrev    24866 non-null float64
# CASTHMA_CrudePrev       24866 non-null float64
# ACCESS2_CrudePrev       24866 non-null float64
# ...

# %%
(t2['LILATracts_halfAnd10']==1).sum()/len(t2['LILATracts_halfAnd10'])
# Out:
# 0.3572749939676667

# %%
t2.head()
# Out:
#             Population2010   PlaceName  TEETHLOST_CrudePrev  STROKE_CrudePrev  \
# 1073000100            3042  Birmingham                 28.9               5.6
# 1073000300            2735  Birmingham                 32.9               5.9
# 1073000400            3338  Birmingham                 28.6               5.7
# 1073000500            2864  Birmingham                 34.0               7.7
# 1073000700            2577  Birmingham                 43.2               9.5
#
#             PHLTH_CrudePrev  OBESITY_CrudePrev  MHLTH_CrudePrev  \
# 1073000100             20.0               47.3             18.6
# 1073000300             20.6               47.5             18.4
# 1073000400             19.3               47.2             17.5
# 1073000500             21.8               49.5             18.2
# 1073000700             25.1               53.4             21.1
#
#             LPA_CrudePrev  KIDNEY_CrudePrev  DENTAL_CrudePrev  \
# ...

# %%
t2[t2['PlaceName']=='Chicago']['LILATracts_halfAnd10']
# Out:
# 17031010100    1
# 17031010201    0
# 17031010202    0
# 17031010300    1
# 17031010400    0
# 17031010501    0
# 17031010502    0
# 17031010503    0
# 17031010600    0
# 17031010701    0
# 17031010702    0
# 17031020100    0
# 17031020200    0
# 17031020301    0
# 17031020302    0
# 17031020400    0
# 17031020500    0
# 17031020601    0
# 17031020602    1
# 17031020701    0
# 17031020702    0
# 17031020801    0
# 17031020802    0
# 17031020901    0
# 17031020902    0
# 17031030101    0
# 17031030102    0
# 17031030103    0
# 17031030104    0
# 17031030200    0
#               ..
# 17031840800    0
# 17031841000    0
# 17031841100    1
# 17031841200    0
# 17031841300    0
# 17031841400    0
# 17031841500    1
# 17031841600    1
# 17031841700    1
# 17031841800    1
# 17031841900    0
# 17031842000    0
# 17031842100    1
# 17031842200    0
# 17031842300    0
# 17031842400    0
# 17031842500    0
# 17031842600    1
# 17031842800    1
# 17031842900    0
# 17031843000    0
# ...

# %%
t2.head()
# Out:
#             Population2010   PlaceName  TEETHLOST_CrudePrev  STROKE_CrudePrev  \
# 1073000100            3042  Birmingham                 28.9               5.6
# 1073000300            2735  Birmingham                 32.9               5.9
# 1073000400            3338  Birmingham                 28.6               5.7
# 1073000500            2864  Birmingham                 34.0               7.7
# 1073000700            2577  Birmingham                 43.2               9.5
#
#             PHLTH_CrudePrev  OBESITY_CrudePrev  MHLTH_CrudePrev  \
# 1073000100             20.0               47.3             18.6
# 1073000300             20.6               47.5             18.4
# 1073000400             19.3               47.2             17.5
# 1073000500             21.8               49.5             18.2
# 1073000700             25.1               53.4             21.1
#
#             LPA_CrudePrev  KIDNEY_CrudePrev  DENTAL_CrudePrev  \
# ...

# %% [markdown]
# High corr:
# - TEETHLOST_CrudePrev

# %%
t2[['TEETHLOST_CrudePrev','STROKE_CrudePrev','PHLTH_CrudePrev','OBESITY_CrudePrev','MHLTH_CrudePrev','LPA_CrudePrev','KIDNEY_CrudePrev','DENTAL_CrudePrev','DIABETES_CrudePrev','CSMOKING_CrudePrev','COREW_CrudePrev','COPD_CrudePrev','CHOLSCREEN_CrudePrev','CASTHMA_CrudePrev','ACCESS2_CrudePrev','PovertyRate','TractSNAP','LILATracts_halfAnd10']]
# Out:
#              TEETHLOST_CrudePrev  STROKE_CrudePrev  PHLTH_CrudePrev  \
# 1073000100                  28.9               5.6             20.0
# 1073000300                  32.9               5.9             20.6
# 1073000400                  28.6               5.7             19.3
# 1073000500                  34.0               7.7             21.8
# 1073000700                  43.2               9.5             25.1
# 1073000800                  28.4               7.3             20.1
# 1073001100                  19.2               5.2             15.6
# 1073001200                  25.6               6.3             17.9
# 1073001400                  24.8               6.7             17.8
# 1073001500                  34.2               7.3             21.6
# 1073001600                  32.2               7.7             21.7
# 1073001902                  31.8               6.5             21.2
# 1073002000                  31.5               6.7             22.0
# ...
