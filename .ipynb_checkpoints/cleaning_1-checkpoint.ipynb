# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score,recall_score,precision_score
import warnings
warnings.filterwarnings('ignore')
from sklearn.naive_bayes import BernoulliNB
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn import svm

# %%
food_desert = pd.ExcelFile('data/DataDownload2015.xlsx')
desert_data = food_desert.parse(2)
desert_data.set_index('CensusTract', inplace=True)

# %%
behav = pd.read_csv('data/500_Cities__Census_Tract-level_Data__GIS_Friendly_Format___2018_release.csv',)
behav.set_index('TractFIPS', inplace=True)

# %%
merge1 = behav.merge(desert_data, how='left', left_index=True, right_index=True)

# %%
merge1.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 1073000100            3042               23.3      (20.6, 26.3)
# 1073000300            2735               28.5      (25.2, 31.7)
# 1073000400            3338               23.9      (20.5, 27.6)
# 1073000500            2864               25.8      (22.0, 29.9)
# 1073000700            2577               29.4      (24.8, 34.2)
#
#             ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  \
# 1073000100                 31.3        (30.3, 32.5)             11.5
# 1073000300                 30.2        (29.0, 31.4)             12.0
# 1073000400                 31.7        (30.3, 33.0)             11.6
# 1073000500                 35.6        (34.1, 37.0)             10.0
# 1073000700                 37.2        (35.8, 38.6)              8.4
#
#               ...     TractSeniors  TractWhite TractBlack  TractAsian  \
# 1073000100    ...            231.0       530.0     2384.0        25.0
# 1073000300    ...            197.0       498.0     1710.0        33.0
# 1073000400    ...            318.0       256.0     2927.0        10.0
# 1073000500    ...            417.0        83.0     2684.0         1.0
# 1073000700    ...            326.0        12.0     2538.0         1.0
#
#            TractNHOPI  TractAIAN TractOMultir  TractHispanic TractHUNV  \
# 1073000100        0.0        7.0         96.0           82.0     141.0
# 1073000300        0.0        4.0        490.0          623.0     287.0
# 1073000400        0.0        7.0        138.0          162.0     246.0
# 1073000500       10.0        5.0         81.0           89.0     345.0
# 1073000700        0.0        1.0         25.0           12.0     198.0
#
#             TractSNAP
# 1073000100      260.0
# 1073000300      377.0
# 1073000400      501.0
# 1073000500      522.0
# 1073000700      506.0
#
# [5 rows x 208 columns]

# %%
merge1['LILATracts_halfAnd10'].fillna(0,inplace=True)

# %%
y=merge1.pop('LILATracts_halfAnd10')

# %%
X=merge1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#             StateAbbr    PlaceName  PlaceFIPS        Place_TractID  \
# 32003005358        NV    Henderson    3231900  3231900-32003005358
# 6037104203         CA  Los Angeles     644000  0644000-06037104203
# 5119004213         AR  Little Rock     541000  0541000-05119004213
# 35001004746        NM  Albuquerque    3502000  3502000-35001004746
# 25025000504        MA       Boston    2507000  2507000-25025000504
#
#              Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 32003005358            3021               10.6      ( 8.8, 12.6)
# 6037104203             5210               30.1      (25.0, 34.9)
# 5119004213             3555                4.3      ( 3.5,  5.5)
# 35001004746            7037               10.1      ( 8.8, 11.5)
# 25025000504            4985                6.7      ( 4.9,  9.6)
#
#              ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  \
# 32003005358                 15.3        (14.4, 16.2)             21.9
# 6037104203                  16.5        (15.7, 17.3)             16.2
# 5119004213                  23.5        (22.3, 25.0)             17.8
# 35001004746                 18.3        (17.8, 18.8)             18.9
# 25025000504                 15.3        (14.5, 16.3)             24.5
#
#                ...     TractSeniors  TractWhite TractBlack  TractAsian  \
# 32003005358    ...            128.0      2407.0       93.0       226.0
# 6037104203     ...            354.0      2077.0      330.0        69.0
# 5119004213     ...            386.0      3229.0      206.0       180.0
# 35001004746    ...            359.0      4874.0      306.0       144.0
# 25025000504    ...            805.0      4057.0      191.0       541.0
#
#             TractNHOPI  TractAIAN TractOMultir  TractHispanic TractHUNV  \
# 32003005358       16.0       13.0        266.0          492.0       5.0
# 6037104203        10.0       26.0       2698.0         4708.0     130.0
# 5119004213         0.0        4.0         75.0           73.0      44.0
# 35001004746        6.0      327.0       1380.0         3316.0      21.0
# 25025000504        3.0        5.0        188.0          318.0    1290.0
#
#              TractSNAP
# 32003005358       45.0
# 6037104203       143.0
# 5119004213         6.0
# 35001004746      263.0
# 25025000504      457.0
#
# [5 rows x 207 columns]

# %%
subset = X_train[['TractWhite',
'TractBlack',
'TractAsian',
'TractNHOPI',
'TractAIAN',
'TractOMultir',
'TractHispanic',
'TractHUNV',
'TractSNAP',
'OHU2010','PovertyRate']]

# %%
test =subset.copy()
test['target']=y_train
test.corr()
# Out:
#                TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# TractWhite       1.000000   -0.351853    0.096984   -0.006491   0.188375
# TractBlack      -0.351853    1.000000   -0.139225   -0.053131  -0.074738
# TractAsian       0.096984   -0.139225    1.000000    0.223674   0.010677
# TractNHOPI      -0.006491   -0.053131    0.223674    1.000000   0.068106
# TractAIAN        0.188375   -0.074738    0.010677    0.068106   1.000000
# TractOMultir     0.137745   -0.041877    0.178707    0.186392   0.384760
# TractHispanic    0.246858   -0.084438    0.068677    0.043886   0.326254
# TractHUNV       -0.042633    0.251363    0.091667   -0.029935   0.036544
# TractSNAP       -0.068180    0.500651   -0.114721    0.022554   0.215912
# OHU2010          0.753049    0.121495    0.278149    0.052096   0.195590
# PovertyRate     -0.393673    0.310474   -0.185139   -0.039068   0.058717
# target          -0.194239    0.242753   -0.174763    0.001355   0.094460
#
#                TractOMultir  TractHispanic  TractHUNV  TractSNAP   OHU2010  \
# TractWhite         0.137745       0.246858  -0.042633  -0.068180  0.753049
# TractBlack        -0.041877      -0.084438   0.251363   0.500651  0.121495
# TractAsian         0.178707       0.068677   0.091667  -0.114721  0.278149
# TractNHOPI         0.186392       0.043886  -0.029935   0.022554  0.052096
# TractAIAN          0.384760       0.326254   0.036544   0.215912  0.195590
# TractOMultir       1.000000       0.864182   0.133728   0.340904  0.212833
# TractHispanic      0.864182       1.000000   0.093238   0.357090  0.206529
# TractHUNV          0.133728       0.093238   1.000000   0.438192  0.309912
# TractSNAP          0.340904       0.357090   0.438192   1.000000  0.226792
# OHU2010            0.212833       0.206529   0.309912   0.226792  1.000000
# PovertyRate        0.154369       0.150234   0.227002   0.556177 -0.266350
# target             0.115291       0.126083  -0.038060   0.378145 -0.108021
#
#                PovertyRate    target
# TractWhite       -0.393673 -0.194239
# TractBlack        0.310474  0.242753
# TractAsian       -0.185139 -0.174763
# TractNHOPI       -0.039068  0.001355
# TractAIAN         0.058717  0.094460
# TractOMultir      0.154369  0.115291
# TractHispanic     0.150234  0.126083
# TractHUNV         0.227002 -0.038060
# TractSNAP         0.556177  0.378145
# OHU2010          -0.266350 -0.108021
# PovertyRate       1.000000  0.491878
# target            0.491878  1.000000

# %%
select_cols=["PovertyRate","TractSNAP"]
for i in X_train.columns:
    if '95CI' not in i:
        select_cols.append(i)

# %%
#test1 = X_train[select_cols]
#test1['target']=y_train
#test1.corr()

# %%
def clean(df):
    df.fillna(df.mean(),inplace=True)
    data1=df[['TEETHLOST_CrudePrev','STROKE_CrudePrev','PHLTH_CrudePrev','OBESITY_CrudePrev','MHLTH_CrudePrev','LPA_CrudePrev','KIDNEY_CrudePrev','DENTAL_CrudePrev','DIABETES_CrudePrev','CSMOKING_CrudePrev','COREW_CrudePrev','COPD_CrudePrev','CHOLSCREEN_CrudePrev','CASTHMA_CrudePrev','ACCESS2_CrudePrev','PovertyRate','TractSNAP']]
    return data1

# %%
df=clean(X_train)

# %%
df.describe()
# Out:
#        TEETHLOST_CrudePrev  STROKE_CrudePrev  PHLTH_CrudePrev  \
# count         18230.000000      18230.000000     18230.000000
# mean             16.121914          3.241755        12.769868
# std               8.731084          1.549651         4.122245
# min               2.800000          0.200000         3.200000
# 25%               9.200000          2.200000         9.600000
# 50%              14.200000          2.900000        12.100000
# 75%              21.300000          3.800000        15.500000
# max              56.500000         21.400000        35.800000
#
#        OBESITY_CrudePrev  MHLTH_CrudePrev  LPA_CrudePrev  KIDNEY_CrudePrev  \
# count       18230.000000     18230.000000   18230.000000      18230.000000
# mean           30.128343        13.111640      25.495299          2.978574
# std             8.236987         3.391219       9.297064          0.960244
# min             9.100000         4.100000       7.100000          0.500000
# 25%            24.100000        10.500000      18.100000          2.300000
# 50%            29.150000        12.700000      24.200000          2.800000
# 75%            35.200000        15.400000      31.900000          3.500000
# max            57.500000        29.400000      62.100000         12.000000
#
#        DENTAL_CrudePrev  DIABETES_CrudePrev  CSMOKING_CrudePrev  \
# count      18230.000000        18230.000000        18230.000000
# mean          61.210000           10.837356           18.107948
# std           12.879767            4.307233            6.010252
# min           18.900000            0.700000            2.000000
# 25%           51.400000            7.900000           13.700000
# 50%           62.800000           10.100000           17.300000
# 75%           71.600000           13.100000           21.700000
# max           88.700000           42.100000           51.400000
#
#        COREW_CrudePrev  COPD_CrudePrev  CHOLSCREEN_CrudePrev  \
# count     18230.000000    18230.000000          18230.000000
# mean         29.773699        6.324547             72.641519
# std           7.148569        2.446618              8.361004
# min          10.700000        1.100000             21.700000
# 25%          24.200000        4.600000             67.700000
# 50%          29.773699        5.900000             73.400000
# 75%          35.100000        7.600000             78.575000
# max          55.100000       24.200000             94.800000
#
#        CASTHMA_CrudePrev  ACCESS2_CrudePrev   PovertyRate     TractSNAP
# count       18230.000000       18230.000000  18230.000000  18230.000000
# mean            9.710439          16.240913     20.520575    236.656699
# std             1.858258           9.020728     14.945389    216.255226
# min             5.100000           2.500000      0.000000      0.000000
# 25%             8.400000           9.400000      8.700000     74.000000
# 50%             9.400000          14.100000     16.900000    180.000000
# 75%            10.800000          20.900000     29.400000    340.000000
# max            18.500000          58.100000    100.000000   2129.000000

# %%
df_test = clean(X_test)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_test.head()
# Out:
#              TEETHLOST_CrudePrev  STROKE_CrudePrev  PHLTH_CrudePrev  \
# 36047005201                 14.4               5.8             14.5
# 17197880115                 16.9               2.6             12.7
# 48439113920                  6.9               1.5              8.1
# 17031711300                 25.0               6.4             17.6
# 12011060125                 15.8               3.5             13.2
#
#              OBESITY_CrudePrev  MHLTH_CrudePrev  LPA_CrudePrev  \
# 36047005201               20.0              9.8           28.8
# 17197880115               39.3             12.5           28.8
# 48439113920               26.7              9.7           19.1
# 17031711300               46.4             15.1           35.4
# 12011060125               33.0             13.6           29.6
#
#              KIDNEY_CrudePrev  DENTAL_CrudePrev  DIABETES_CrudePrev  \
# 36047005201               4.9              68.2                14.9
# 17197880115               2.6              56.5                10.1
# 48439113920               1.8              71.8                 7.0
# 17031711300               4.8              45.0                19.3
# 12011060125               3.0              58.8                12.7
#
#              CSMOKING_CrudePrev  COREW_CrudePrev  COPD_CrudePrev  \
# 36047005201                12.0             26.3            10.0
# 17197880115                20.5             27.4             5.9
# 48439113920                14.7             40.3             3.6
# 17031711300                22.9             20.2             9.0
# 12011060125                19.1             27.4             6.6
#
#              CHOLSCREEN_CrudePrev  CASTHMA_CrudePrev  ACCESS2_CrudePrev  \
# 36047005201                  87.7               10.1                9.0
# 17197880115                  69.7               10.1               16.6
# 48439113920                  78.6                8.1               12.7
# 17031711300                  76.2               13.3               16.4
# 12011060125                  79.6                9.0               21.5
#
#              PovertyRate  TractSNAP
# 36047005201         32.1      388.0
# 17197880115         17.4      151.0
# 48439113920          0.5       28.0
# 17031711300         28.0      151.0
# 12011060125         15.0      103.0

# %% [markdown]
# ## REMOVE AFTER THIS

# %%
model_log = LogisticRegression(penalty='l1')
model_log.fit(df,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print("TRAIN")
print("ROC_AUC Logistic: ", cross_val_score(LogisticRegression(),df,y_train,cv=5,scoring='roc_auc').mean())
print("Accuracy Logistic: ", cross_val_score(LogisticRegression(),df,y_train,cv=5).mean())
print("f1 Logistic: ", cross_val_score(LogisticRegression(),df,y_train,cv=5,scoring='f1').mean())
# Out:
# TRAIN
# ROC_AUC Logistic:  0.8664619834948086
# Accuracy Logistic:  0.7860669226549644
# f1 Logistic:  0.6834526480336256

# %%
y_pred = model_log.predict(df_test)

# %%
print("TEST")
print("ROC_AUC Logistic: ", roc_auc_score(y_test,y_pred))
print("Accuracy Logistic: ", accuracy_score(y_test,y_pred))
print("f1 Logistic: ", f1_score(y_test,y_pred))
# Out:
# TEST
# ROC_AUC Logistic:  0.7528683028793485
# Accuracy Logistic:  0.7849665924276169
# f1 Logistic:  0.6811953112101701

# %%
model_rf = RandomForestClassifier()
model_rf.fit(df,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = model_rf.predict(df_test)

# %%
(y_test == 1).sum()
# Out:
# 3232

# %%
print("TRAIN")
print("ROC_AUC RF: ", cross_val_score(RandomForestClassifier(),df,y_train,cv=5,scoring='roc_auc').mean())
print("Accuracy RF: ", cross_val_score(RandomForestClassifier(),df,y_train,cv=5).mean())
print("f1 RF: ", cross_val_score(RandomForestClassifier(),df,y_train,cv=5,scoring='f1').mean())
# Out:
# TRAIN
# ROC_AUC RF:  0.8887182107975595
# Accuracy RF:  0.8129456939111355
# f1 RF:  0.7371738490157967

# %%
print("TEST")
print("ROC_AUC RF: ", roc_auc_score(y_test,y_pred))
print("Accuracy RF: ", accuracy_score(y_test,y_pred))
print("f1 RF: ", f1_score(y_test,y_pred))
# Out:
# TEST
# ROC_AUC RF:  0.8304823632154448
# Accuracy RF:  0.8386414253897551
# f1 RF:  0.781414994720169

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=9, min_samples_leaf=13, min_samples_split=2)

# %%
print("TRAIN")
print("ROC_AUC DT: ", cross_val_score(model,df,y_train,cv=5,scoring='roc_auc').mean())
print("Accuracy DT: ", cross_val_score(model,df,y_train,cv=5).mean())
print("f1 DT: ", cross_val_score(model,df,y_train,cv=5,scoring='f1').mean())
# Out:
# TRAIN
# ROC_AUC DT:  0.8755032882455989
# Accuracy DT:  0.8087218869994514
# f1 DT:  0.7393988175342292

# %%
model.fit(df,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=9,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=13, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = model.predict(df_test)

# %%
print("TEST")
print("ROC_AUC DT: ", roc_auc_score(y_test,y_pred))
print("Accuracy DT: ", accuracy_score(y_test,y_pred))
print("f1 DT: ", f1_score(y_test,y_pred))
# Out:
# TEST
# ROC_AUC DT:  0.7894783247896814
# Accuracy DT:  0.8063474387527839
# f1 DT:  0.7305129397179606

# %%
model = GradientBoostingClassifier()
model.fit(df,y_train)
y_pred = model.predict(df_test)

# %%
print("TEST")
print("ROC_AUC DT: ", roc_auc_score(y_test,y_pred))
print("Accuracy DT: ", accuracy_score(y_test,y_pred))
print("f1 DT: ", f1_score(y_test,y_pred))
# Out:
# TEST
# ROC_AUC DT:  0.8236291400538802
# Accuracy DT:  0.8307349665924276
# f1 DT:  0.7724550898203593

# %%
clf = svm.SVC()

# %%
clf.fit(df,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovo', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = clf.predict(df_test)

# %%
print("TEST")
print("ROC_AUC DT: ", roc_auc_score(y_test,y_pred))
print("Accuracy DT: ", accuracy_score(y_test,y_pred))
print("f1 DT: ", f1_score(y_test,y_pred))
# Out:
# TEST
# ROC_AUC DT:  0.5039842743407952
# Accuracy DT:  0.6419821826280624
# f1 DT:  0.022499239890544236

# %%
model = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='log2', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)

# %%
model.fit(df,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='log2', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = model.predict(df_test)

print("TEST on RF_GS")
print("ROC_AUC score: ", roc_auc_score(y_test,y_pred))
print("Accuracy score: ", accuracy_score(y_test,y_pred))
print("f1 score: ", f1_score(y_test,y_pred))
print("recall score: ", recall_score(y_test,y_pred))
print("precision score: ", precision_score(y_test,y_pred))
# Out:
# TEST on RF_GS
# ROC_AUC score:  0.8304823632154448
# Accuracy score:  0.8386414253897551
# f1 score:  0.781414994720169
# recall score:  0.8013613861386139
# precision score:  0.762437444804239
