# %%
import yaml
from pymongo import MongoClient
import time
from datetime import datetime,timedelta

# %%
client = MongoClient()
db = client['capstone']
coll=db['twitter']

# %%
def load_api_key(filename='twitter_api_key.yaml'):
    """Load Yelp API client ID and client secret and return them as a dictionary."""
    with open(filename) as f:
        return yaml.load(f)

# %%
from twitter import *
key = load_api_key()
consumer_key = key['consumer_key']
consumer_secret = key['consumer_secret']
access_token = key['access_token']
access_token_secret = key['access_token_secret']

t = Twitter(
    auth=OAuth(access_token, access_token_secret,consumer_key, consumer_secret))

# %%
x=t.search.tweets(q=("Trader Joe\'s -filter:retweets"), count=20,tweet_mode='extended')['statuses']

# %%
c = 0
lst = []
s = []
sent=[]
for i,tweet in enumerate(x):
            if tweet['id'] not in s:
                date = tweet['created_at']
                current = datetime.strptime(date, '%a %b %d %H:%M:%S +0000 %Y')
                lst.append(tweet['full_text'])
                s.append(tweet['id'])
                ss = sid.polarity_scores(tweet['full_text'])
                sent.append(ss)
                #coll.insert_one({'tweet': tweet, 'sentiment':ss})

# %%
lst
# Out:
# ['I’m craving chocolate so I’m eating Trader Joe’s organic popcorn instead because I live in L.A. and that’s how we maintain our self-righteousness.',
#  'Shopping at Trader Joe’s when barely anyone else is in there is a spiritual experience',
#  'Currently sitting IN my PARKED car in the Trader Joe’s Parking lot. I’m drunk with power!!',
#  'PSA: stop what you’re doing rn, drive to Trader Joe’s and buy these https://t.co/OceA89B4pj',
#  "@backfliptornado Trader Joe's sells it in the freezer! It's good!",
#  "@SteakAndIron I got some good dark chocolate from Trader Joe's the other day, the no added sugar type, it had the same affect as a laxative",
#  'Hey @jay_eatz how are these grill marks for ya? I thought of you, the chicken master when I was making them 😜 Marinated in Trader Joe’s Soyaki. #yum #grillingchats #bbq https://t.co/HS61p6jq2N',
#  "I'm at Trader Joe's in Shoreline, WA https://t.co/SPxkYNlhEj https://t.co/NfUB3z5En4",
#  "@UffdaJen look what I found at Trader Joe's (Brentwood) https://t.co/iLdsoUTbdd",
#  "Shopping List | Trader Joe's https://t.co/KvwrnhB6Ly",
#  "If there's anything we can count on, it's Trader Joe's to have the most delicious items in stock, and #onIBTtoday we are sharing the most delicious recipes you can meal prep with goods from good ol' TJ's! https://t.co/pnveEFNNPo https://t.co/x4nwrOGN3P",
#  'There is no Trader Joe’s around where I will be living and I’m honestly going to cry about it??? Also no Whole Foods??? HELLO??',
#  'I made it in and out of Trader Joe’s without buying any ice cream, cookies, crackers, chips, or any other c-food (well, one wedge of cheese). This is an accomplishment. And a #festivus miracle, if we’re being honest.',
#  "My Trader Joe's haul inspired by @tina_bean02 https://t.co/9uylmyjz12",
#  '#vegan crabcake sandwich (Trader Joe’s jackfruit “crab cakes.”) 😋 https://t.co/fLXtSX7E8I',
#  '@dave_doors And why did you do this before your trip to India, and not, say, last Thursday before your trip to Trader Joe’s?\n\nYou can use science words.',
#  '@glubwilsen The woman who rang me up at Trader Joe\'s was wearing a nametag that said "VAS" and I remembered that someone told me once their partner works at Trader Joe\'s and her name is VAS but I couldn\'t remember who so I didn\'t say anything.',
#  "The soy chorizo they sell at Trader Joe's is really good.  I just made a sandwich with some.",
#  'gonna have to say I do miss VB for the fact that you can go to the grocery store without making it a 3 hour ordeal...in the ny trader joe’s someone will murder you over the last bag of apples i’m tired',
#  "I'm so fucking proud of myself.\n\nI've remembered to bring my Trader Joe's reusable bags with me for the first time of trying for 2 years"]

# %%
len(x)
# Out:
# 20

# %%
sid=SentimentIntensityAnalyzer()
ss = sid.polarity_scores("I like candy yum")
ss
# Out:
# {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.3612}

# %%
for tweet in x:
    #print(tweet['text'])
    #print("Sentiment:")
    ss = sid.polarity_scores(tweet['text'])
    #print(ss)
    coll.insert_one({'tweet':tweet,'sentiment':ss})
# Out:
# THEYRE PLAYING TWO GHOSTS ON SAFEWAY THIS IS NOT A DRILL
# Sentiment:
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}
# 10 years ago today we were jamming in Austin, Texas filming SXSW for Def Jam Records. A slightly less known Kanye W… https://t.co/pYrBz4XyPP
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Another reason to holiday on Maui in March is that their Girl Scouts are still selling cookies. I picked up a coupl… https://t.co/ekfynMgsiR
# Sentiment:
# {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.4019}
# 3/26/2019:  Checked in buying two-months’ grocery supplies. (@ Safeway Food &amp; Drug) on #Yelp https://t.co/cpW4sVsIl6
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TONIGHT: Queen Anne Safeway developer hosting last general meeting to discuss plans to double store's size with new… https://t.co/upgrWGd1J4
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# That Safeway sandwich I just had hit different
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# RT @krisaguayo: Fun things to do in Kent
# Go to the Kent Fred Meyer
# Go to the Covington Fred Meyer
# Go to Target
# Go to Costco
# Go to the…
# Sentiment:
# {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.5106}
# There is no line at Safeway is getting a loaf of bread and a liter of vodka.
# Sentiment:
# {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.296}
# (Mission, San Francisco) Two Security Guards Fighting Safeway Customer - reported on @CitizenApp_SF #ProtectTheWorld https://t.co/7Azuk6S9YO
# Sentiment:
# {'neg': 0.148, 'neu': 0.71, 'pos': 0.142, 'compound': -0.0258}
# Damonte Ranch residents can look forward to a new Safeway store. Albertsons Companies, Inc. recently closed escrow… https://t.co/8WlhPzLxVG
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# RT @Zukerooty: History repeats itself... now at your local Safeway https://t.co/52bxO8Fk6n
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 10 years ago today we were jamming in Austin, Texas filming SXSW for Def Jam Records. A slightly less known Kanye W… https://t.co/ByT8sUEhx5
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @Safeway Thanks for the encouragement boss😘
# Sentiment:
# {'neg': 0.0, 'neu': 0.412, 'pos': 0.588, 'compound': 0.6908}
# @Ronalpha94 Jajajaj el target nunca falla, Whole Foods está más caro, no nos animamos a ir al Safeway
# Sentiment:
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.296}
# @DailyTweter Keep going! Don't give up! We believe in you! 💰🧐🎩
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Consider donating or purchasing a gift card to support our programs. Gift cards are used for food, clothing, gas, c… https://t.co/byw5KRWPlL
# Sentiment:
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.8176}
# like safeway is cool i guess because they make it right in front of you, same with wholefoods but oh man trader joe… https://t.co/AebdGw7b5p
# Sentiment:
# {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.34}
# Probably have more luck winning a $1,000,000 from Safeway than I do a #RedLight from @BudweiserCanada #cellyszn… https://t.co/BYVSE1LMKt
# Sentiment:
# {'neg': 0.0, 'neu': 0.651, 'pos': 0.349, 'compound': 0.7889}
# I came back to work at Harper’s today at Harper’s Choice Safeway with my medals and ribbons from the World Games an… https://t.co/a5k4ntUrmS
# Sentiment:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# RT @r0wdy_: @mkr_ultra Yeah definitely don't need to call the deli dude at safeway a cheesemonger
# Sentiment:
# {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'compound': 0.5994}

# %%
list(coll.find().limit(5))
# Out:
# [{'_id': ObjectId('5c9a9e84aaedff5572f54c39'),
#   'created_at': 'Tue Mar 26 21:26:58 +0000 2019',
#   'id': 1110654398470840320,
#   'id_str': '1110654398470840320',
#   'text': 'THEYRE PLAYING TWO GHOSTS ON SAFEWAY THIS IS NOT A DRILL',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 96489626,
#    'id_str': '96489626',
#    'name': '•°｡💐˚ᵐᵃᵈᶤ ᵐᵉʳᶜᵘʳʸ˚｡💐°•',
#    'screen_name': 'MadiOnTheMoon',
#    'location': '',
#    'description': "'the fun girls with the blue hair and the lovely madi.'                                                                          -emerson barrett",
#    'url': 'https://t.co/afS8RXS8nJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/afS8RXS8nJ',
#        'expanded_url': 'http://vsco.co/fizzlinglemonsoda',
#        'display_url': 'vsco.co/fizzlinglemons…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 376,
#    'friends_count': 471,
#    'listed_count': 12,
#    'created_at': 'Sun Dec 13 05:06:26 +0000 2009',
#    'favourites_count': 31143,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 62925,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '050505',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1104512374462021632/4uJXmIyZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1104512374462021632/4uJXmIyZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/96489626/1552976908',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EBEBEB',
#    'profile_text_color': '0A0A0A',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'_id': ObjectId('5c9a9e84aaedff5572f54c3a'),
#   'created_at': 'Tue Mar 26 21:24:42 +0000 2019',
#   'id': 1110653829073326086,
#   'id_str': '1110653829073326086',
#   'text': '10 years ago today we were jamming in Austin, Texas filming SXSW for Def Jam Records. A slightly less known Kanye W… https://t.co/pYrBz4XyPP',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/pYrBz4XyPP',
#      'expanded_url': 'https://twitter.com/i/web/status/1110653829073326086',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 404718653,
#    'id_str': '404718653',
#    'name': 'HendyStreet',
#    'screen_name': 'HendyStreetPros',
#    'location': 'Wilmington, N.C. ',
#    'description': '🎥 Filmmaker/Producer  - Thinking inside the box since 2007... 📹',
#    'url': 'https://t.co/fwH8yDqJsM',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/fwH8yDqJsM',
#        'expanded_url': 'http://www.hendystreet.com',
#        'display_url': 'hendystreet.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 207,
#    'friends_count': 531,
#    'listed_count': 28,
#    'created_at': 'Fri Nov 04 09:46:27 +0000 2011',
#    'favourites_count': 774,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 2031,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/879197179184906240/WHNdTFnY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/879197179184906240/WHNdTFnY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/404718653/1508697123',
#    'profile_link_color': '89C9FA',
#    'profile_sidebar_border_color': 'C6E2EE',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'_id': ObjectId('5c9a9e84aaedff5572f54c3b'),
#   'created_at': 'Tue Mar 26 21:21:55 +0000 2019',
#   'id': 1110653128200912896,
#   'id_str': '1110653128200912896',
#   'text': 'Another reason to holiday on Maui in March is that their Girl Scouts are still selling cookies. I picked up a coupl… https://t.co/ekfynMgsiR',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/ekfynMgsiR',
#      'expanded_url': 'https://twitter.com/i/web/status/1110653128200912896',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitterrific.com/mac" rel="nofollow">Twitterrific for Mac</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50441235,
#    'id_str': '50441235',
#    'name': 'Ken Ryall',
#    'screen_name': 'kenryall',
#    'location': 'Austin, TX',
#    'description': 'iOS & Mac developer at Evernote. Pilot of an M20E at KHYI.',
#    'url': 'https://t.co/YQo7fcfues',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/YQo7fcfues',
#        'expanded_url': 'http://www.kenryall.com',
#        'display_url': 'kenryall.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 341,
#    'friends_count': 1038,
#    'listed_count': 23,
#    'created_at': 'Wed Jun 24 21:09:53 +0000 2009',
#    'favourites_count': 5002,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1350,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/779350741865541632/KHMEkqRu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/779350741865541632/KHMEkqRu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50441235/1428720682',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'_id': ObjectId('5c9a9e84aaedff5572f54c3c'),
#   'created_at': 'Tue Mar 26 21:21:07 +0000 2019',
#   'id': 1110652928572809216,
#   'id_str': '1110652928572809216',
#   'text': '3/26/2019:  Checked in buying two-months’ grocery supplies. (@ Safeway Food &amp; Drug) on #Yelp https://t.co/cpW4sVsIl6',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Yelp', 'indices': [91, 96]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/cpW4sVsIl6',
#      'expanded_url': 'https://www.yelp.com/biz/safeway-food-and-drug-placerville-4?pt=check_in&ref=twitter&utm_campaign=CheckIn&utm_medium=twitter&utm_source=ishare&v=4b',
#      'display_url': 'yelp.com/biz/safeway-fo…',
#      'indices': [97, 120]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://www.yelp.com/" rel="nofollow">Yelp</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 344347312,
#    'id_str': '344347312',
#    'name': 'Shirley M. Jones',
#    'screen_name': 'VieH2O',
#    'location': 'USA',
#    'description': 'B.A. Degree: Cinematography-San Francisco State University/JCC A.A. Liberal Arts; Retired Cinematographer/SAG/AFTRA Actor/Stunt Double/Grammy Member/USAF DAV',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 202,
#    'friends_count': 132,
#    'listed_count': 19,
#    'created_at': 'Thu Jul 28 22:49:06 +0000 2011',
#    'favourites_count': 35236,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 23173,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/861047435132420096/P8NdgQ7f_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/861047435132420096/P8NdgQ7f_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/344347312/1389372004',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'_id': ObjectId('5c9a9e84aaedff5572f54c3d'),
#   'created_at': 'Tue Mar 26 21:20:06 +0000 2019',
#   'id': 1110652669746663425,
#   'id_str': '1110652669746663425',
#   'text': "TONIGHT: Queen Anne Safeway developer hosting last general meeting to discuss plans to double store's size with new… https://t.co/upgrWGd1J4",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/upgrWGd1J4',
#      'expanded_url': 'https://twitter.com/i/web/status/1110652669746663425',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 48864323,
#    'id_str': '48864323',
#    'name': 'Queen Anne & Magnolia News',
#    'screen_name': 'qamagnews',
#    'location': 'Seattle',
#    'description': 'The official page for Queen Anne & Magnolia News. Local news for Queen Anne, Magnolia, Uptown, & Interbay. Our other papers: @SeaCityLiving & @MadisonParkTime',
#    'url': 'http://t.co/fy0RYRu4AN',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/fy0RYRu4AN',
#        'expanded_url': 'http://www.queenannenews.com/',
#        'display_url': 'queenannenews.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1635,
#    'friends_count': 575,
#    'listed_count': 57,
#    'created_at': 'Fri Jun 19 23:27:57 +0000 2009',
#    'favourites_count': 82,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 5222,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/975999709746675713/-WW3KS4O_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/975999709746675713/-WW3KS4O_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48864323/1521155517',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %%
for tweet in t.search.tweets(q="safeway", count=10)['statuses']:
    print(tweet['text'])
# Out:
# (Mission, San Francisco) Two Security Guards Fighting Safeway Customer - reported on @CitizenApp_SF #ProtectTheWorld https://t.co/7Azuk6S9YO
# Damonte Ranch residents can look forward to a new Safeway store. Albertsons Companies, Inc. recently closed escrow… https://t.co/8WlhPzLxVG
# RT @Zukerooty: History repeats itself... now at your local Safeway https://t.co/52bxO8Fk6n
# 10 years ago today we were jamming in Austin, Texas filming SXSW for Def Jam Records. A slightly less known Kanye W… https://t.co/ByT8sUEhx5
# @Safeway Thanks for the encouragement boss😘
# @Ronalpha94 Jajajaj el target nunca falla, Whole Foods está más caro, no nos animamos a ir al Safeway
# @DailyTweter Keep going! Don't give up! We believe in you! 💰🧐🎩
# Consider donating or purchasing a gift card to support our programs. Gift cards are used for food, clothing, gas, c… https://t.co/byw5KRWPlL
# like safeway is cool i guess because they make it right in front of you, same with wholefoods but oh man trader joe… https://t.co/AebdGw7b5p
# Probably have more luck winning a $1,000,000 from Safeway than I do a #RedLight from @BudweiserCanada #cellyszn… https://t.co/BYVSE1LMKt

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/karinapatel/nltk_data...

# %%
#words = ['safeway','albertsons','ralphs','kroger','trader joe\'s','whole foods','jewel-osco', 'pavilions', 'food 4 less']
words=['randalls','tom thumb','star market','vons','united supermarkets','amigos','acme markets', 'carrs']
for query in words:
    req_count = 0
    current = datetime.now()
    Prior = datetime.now() - timedelta(days=1)
    c = 0
    lst = []
    s = []
    q = query + " -filter:retweets"
    while current>Prior:
        if c == 0:
            Query = t.search.tweets(q=q,result_type='recent',count=100,tweet_mode='extended')
            next_cursor = Query['search_metadata']['next_results']
            c+=1
        else:
            Query = t.search.tweets(q=q,result_type='recent',count=100,max_id=max_id,tweet_mode='extended')
            next_cursor = Query['search_metadata']['next_results']
            c+=1
        for i,tweet in enumerate(Query['statuses']):
            if tweet['id'] not in s and query in tweet['full_text'].lower():
                date = tweet['created_at']
                current = datetime.strptime(date, '%a %b %d %H:%M:%S +0000 %Y')
                lst.append(tweet['full_text'])
                s.append(tweet['id'])
                ss = sid.polarity_scores(tweet['full_text'])
                coll.insert_one({'full_data': tweet,'text': tweet['full_text'], 'sentiment':ss})
            req_count+=1
        max_id = tweet['id']
        if req_count>450*99:
            time.sleep(60*15)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     340         try:
# --> 341             handle = urllib_request.urlopen(req, **kwargs)
#     342             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# /anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# /anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# /anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# /anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /anaconda3/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-219-b04cdd52a98d> in <module>
#      15             c+=1
#      16         else:
# ---> 17             Query = t.search.tweets(q=q,result_type='recent',count=100,max_id=max_id,tweet_mode='extended')
#      18             next_cursor = Query['search_metadata']['next_results']
#      19             c+=1
#
# /anaconda3/lib/python3.6/site-packages/twitter/api.py in __call__(self, **kwargs)
#     332             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     333         else:
# --> 334             return self._handle_response(req, uri, arg_data, _timeout)
#     335
#     336     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# /anaconda3/lib/python3.6/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     365                 return []
#     366             else:
# --> 367                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     368
#     369     def _handle_response_with_retry(self, req, uri, arg_data, _timeout=None):
#
# TwitterHTTPError: Twitter sent status 429 for URL: 1.1/search/tweets.json using parameters: (count=100&max_id=1110650009610043392&oauth_consumer_key=5qQR2X5N7Gciq6grxHKb7FN4H&oauth_nonce=7844608285790643959&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1553644761&oauth_token=1099364574652915712-n2qrqEOXBeRYpdILcrmbdsK5hLjET8&oauth_version=1.0&q=amigos%20-filter%3Aretweets&result_type=recent&tweet_mode=extended&oauth_signature=O0PgdYGOJi8eumZLMZlzwyBzXcU%3D)
# details: {'errors': [{'message': 'Rate limit exceeded', 'code': 88}]}

# %%
tweet
# Out:
# {'created_at': 'Sun Mar 24 03:26:02 +0000 2019',
#  'id': 1109657597982859265,
#  'id_str': '1109657597982859265',
#  'full_text': '@asiameoww @FollowYourHeart @FieldRoast I LOVE the Chao cheese! And I know! Where I live, we’re FINALLY starting to get more and more options. Check your local co-ops and Food 4 Less!! They have SO many options it’s insane!',
#  'truncated': False,
#  'display_text_range': [40, 223],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'asiameoww',
#     'name': 'a s i a',
#     'id': 198607195,
#     'id_str': '198607195',
#     'indices': [0, 10]},
#    {'screen_name': 'FollowYourHeart',
#     'name': 'Follow Your Heart',
#     'id': 172834226,
#     'id_str': '172834226',
#     'indices': [11, 27]},
#    {'screen_name': 'FieldRoast',
#     'name': 'Field Roast',
#     'id': 111689551,
#     'id_str': '111689551',
#     'indices': [28, 39]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': 1109657158029729793,
#  'in_reply_to_status_id_str': '1109657158029729793',
#  'in_reply_to_user_id': 198607195,
#  'in_reply_to_user_id_str': '198607195',
#  'in_reply_to_screen_name': 'asiameoww',
#  'user': {'id': 1005154877209657345,
#   'id_str': '1005154877209657345',
#   'name': '𝔻𝕖𝕤𝕥𝕒𝕟𝕪 𝔸𝕝𝕖𝕩𝕒𝕟𝕕𝕣𝕒 🌿',
#   'screen_name': 'dezzyalexandra',
#   'location': '',
#   'description': 'Actress • Vegan • Spiritual • YouTube channel coming up!! ♡ // Pisces 🌞, Pisces 🌙, Gemini ↑',
#   'url': 'https://t.co/iDHHVPTI0O',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/iDHHVPTI0O',
#       'expanded_url': 'http://Instagram.com/dezzyalexandra',
#       'display_url': 'Instagram.com/dezzyalexandra',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 167,
#   'friends_count': 131,
#   'listed_count': 1,
#   'created_at': 'Fri Jun 08 18:29:32 +0000 2018',
#   'favourites_count': 16289,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 4214,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1101352389586563072/I2iRErbE_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1101352389586563072/I2iRErbE_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1005154877209657345/1546128787',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
list(db.twitter.find().limit(2))[0]['full_data']['geo']==None
# Out:
# True

# %%
list(db.twitter.find().limit(2))[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-216-a3536f415b35> in <module>
# ----> 1 list(db.twitter.find().limit(2))[0].full_data
#
# AttributeError: 'dict' object has no attribute 'full_data'
